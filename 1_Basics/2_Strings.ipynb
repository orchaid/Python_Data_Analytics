# %% [markdown]
# # Methods
# Python uses a dot notation to access methods ->
# **variable.method()**
#
# to call a method we must use () at the end

# %%
# There are different methods for different classes
# for example i can add or subtract from an int (data type) class but only add for a str
total_new_salary = 100000
bonus_salary = 10000
old_salary = total_new_salary - bonus_salary

old_salary
# Out:
# 90000

# %%
job_title = 'data analysis'
remove_word = 'analysis'
#desired_word = job_title - remove_word
type(job_title), type (old_salary)
# can't perform subtractions on str unlike int where you can
# Out:
# (str, int)

# %%
'data' + ' nerd' # the + opperand works with str
# Out:
# 'data nerd'

# %%
'data nerd'.capitalize()
# Out:
# 'Data nerd'

# %%
str(1000) # we can use srt() or flt() or int() as a function to turn an object data type into string
# Out:
# '1000'

# %% [markdown]
# # positional arguments and key words
# positional arguments on the **left of /** and key words on the **right of** the /
#
# - no words are written in positional arguments, but in key words argument i have the option to write it or leave it <it's better to write it>

# %%
word ='Python Learning'

# %%
word.upper(),word.lower(),word.split(sep = ' ',maxsplit = 1) # all of these are built in method for str
# Out:
# ('PYTHON LEARNING', 'python learning', ['Python', 'Learning'], 'd')

# %%
help(str) # we use help function to see the different methods available for functions instead of memorizing
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
word.split() # positional arguments on the left of / and key words on the right of the /
# no words are written in positional arguments, but in key words argument i have the option to write it or leave it <it's better to write it>
# Out:
# ['Python', 'Learning']

# %%
##,word.join('d'),word.replace('n','t',2)

# %% [markdown]
# ## magic methods or dunder method
# some of them are replaced with operators < like * and + > in case of a string

# %%
str.__add__('data', ' analysis')
# Out:
# 'data analysis'

# %%
'data'.__add__( ' analysis')
# Out:
# 'data analysis'

# %%
'data' + ' analysis' # some opperands overwrite some dunder methods like the plus instead of __add__
# Out:
# 'data analysis'

# %%
len('data analysis') # some dunder methods h can be overwritten by some functions
# Out:
# 13
