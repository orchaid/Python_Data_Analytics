# %%
# Install datasets library (if not already installed)
# !pip install datasets
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Loading Data
data = load_dataset('lukebarousse/data_jobs')
df = data['train'].to_pandas()
# Out:
# ...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %% [markdown]
# # Simple Example

# %%
# plots the y based on the x
x =[1,2,3,4,5]
y =[1,2,3,4,5]
plt.plot(x, y)
plt.show()      # displays all open fiqures

# %% [markdown]
# # Ploting Job posted date

# %%
df.job_posted_date.head()
# Out:
# 0   2023-06-16 13:44:15
# 1   2023-01-14 13:18:07
# 2   2023-10-10 13:14:55
# 3   2023-07-04 13:01:41
# 4   2023-08-07 14:29:36
# Name: job_posted_date, dtype: datetime64[ns]

# %%
plt.plot(df.job_posted_date, df.job_posted_date)

# %%
df.job_posted_date.count()
# Out:
# 785741

# %%
df.job_posted_date.value_counts()
# Out:
# job_posted_date
# 2023-12-08 07:24:37    10
# 2023-01-08 00:19:57    10
# 2023-09-17 00:28:49    10
# 2023-09-07 00:07:24    10
# 2023-07-22 07:25:54    10
#                        ..
# 2023-05-17 17:27:41     1
# 2023-05-28 17:51:07     1
# 2023-09-05 17:10:27     1
# 2023-09-02 17:02:18     1
# 2023-03-12 06:32:36     1
# Name: count, Length: 607192, dtype: int64

# %%
date_count = df.job_posted_date.value_counts()

# %%
type(date_count) # it's a series not a dataframe anymore
# Out:
# pandas.core.series.Series

# %%
plt.plot(date_count.index, date_count.values) # the date_count is not sorted, that's why we get this miss

# %%
# Sorting the index date_count using sort_index not sort_value
date_count = date_count.sort_index()
date_count
# Out:
# job_posted_date
# 2023-01-01 00:00:04    1
# 2023-01-01 00:00:07    1
# 2023-01-01 00:00:22    1
# 2023-01-01 00:00:24    1
# 2023-01-01 00:00:27    1
#                       ..
# 2023-12-31 23:40:18    2
# 2023-12-31 23:40:22    2
# 2023-12-31 23:40:31    2
# 2023-12-31 23:40:32    1
# 2023-12-31 23:59:58    2
# Name: count, Length: 607192, dtype: int64

# %%
plt.plot(date_count.index, date_count.values) # now it's sorted, but still not right

# The reason why it isn't useful is because the agregation method (count vased on single seperated days) isn't correct
# To make it right we should aggregate based on day-month-quarter-year

# %% [markdown]
# # Plotting Job Posted Month
# - matplotlib.pyplot is a **stacking oriented** not object oriented

# %%
month_count = df.job_posted_date.dt.month.value_counts()

month_count = month_count.sort_index() # dont forget to sort the index
month_count
# Out:
# job_posted_date
# 1     91822
# 2     64578
# 3     64084
# 4     62919
# 5     52104
# 6     61572
# 7     63777
# 8     75162
# 9     62359
# 10    66611
# 11    64450
# 12    56303
# Name: count, dtype: int64

# %%
plt.plot(month_count.index, month_count)
plt.title('job postings over months')
plt.xlabel('Month')
plt.ylabel('job posted')
plt.show()

# Stack oriented

# %% [markdown]
# # DataFrame VS Series
# - One-dimensional:  It's essentially a single column of data.
# - Indexed: The index can be numbers, dates, or even strings.
# - Diverse Data Types: A Series can hold any data type, However, all elements within a Series must be of the same data type.
# -  `column of data within a dataframe is also a series`

# %%
pd.Series([40,40,44,50,500], index = ['a', 'b', 'c', 'd','f'])   # data type for pandas like the np.array([]) data type in numpy but of course different.
# Out:
# a     40
# b     40
# c     44
# d     50
# f    500
# dtype: int64

# %%
series= pd.Series([1,3],index= ['R','A'])
series.values, series.index
# Out:
# (array([1, 3]), Index(['R', 'A'], dtype='object'))

# %% [markdown]
# # Bar Charts - Counts of Job Postings
# - Used to compare different groups or to track changes over time.
# - Best for categorical data comparison.
# - In Python we have two types of bar charts:
# - 1. Bar Plots - bars are vertical
# - 2. Horizontal Bar Plot - bars are horizontal

# %%
df.groupby('job_title_short')['job_title_short'].count().sort_values()
job_count = df.groupby('job_title_short')['job_title_short'].count().sort_values()
job_count
# ascending
# Out:
# job_title_short
# Cloud Engineer                12331
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Scientist         36957
# Senior Data Engineer          44563
# Software Engineer             44929
# Business Analyst              49063
# Data Scientist               172286
# Data Engineer                186241
# Data Analyst                 196075
# Name: job_title_short, dtype: int64

# %%
plt.barh(job_count.index, job_count) # plt starts ploting from the bottom and then upwards in horizontal bar
plt.show()
# Out:
# <BarContainer object of 10 artists>

# %%
# or descending
df.job_title_short.value_counts()
# or job_count.sort_values(ascendig = True) and then plot bar
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64
