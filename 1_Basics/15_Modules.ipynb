# %% [markdown]
# # Types of functions
#
# | **Type of Function**       | **Description**                                                                 |
# |----------------------------|---------------------------------------------------------------------------------|
# | **Built-in Functions**     | Predefined functions in Python (e.g., `print()`, `len()`, `type()`).            |
# | **User-defined Functions** | Functions created by users using the `def` keyword.                            |
# | **Lambda Functions**       | Anonymous functions defined using the `lambda` keyword for simple operations.  |
# | **Standard Library Functions** | Functions from Python's standard library modules (e.g., `math.sqrt()`, `os.path()`). |
# | **Third-party Functions**  | Functions provided by external libraries or frameworks (e.g., `numpy.mean()`, `pandas.DataFrame()`). |

# %%
import my_module

my_module.skills # instance
# Out:
# ['SQL', 'Python', 'Excel']

# %%
my_module.fav('SQL')
# Out:
# 'SQL is my favorite skill'

# %%
from my_module import *

# %%
sal_calculator(10000)
# Out:
# 11000.0

# %%
bonus_calculator(11000,10000)
# Out:
# 0.1

# %%
help(my_module)
# Out:
# Help on module my_module:
#
# NAME
#     my_module
#
# FUNCTIONS
#     bonus_calculator(total, base)
#         calculate the bonus rate based on the total salary and the base salary.
#         Args:
#           total (float): the total salary.
#           base (float): the base salary.
#         Returns:
#           float: the bonus rate.
#
#     fav(skill)
#
#     sal_calculator(base, bonus=0.1)
#         calculate the total salary based on the salary and the bonus.
#         Args:
#           base (float): the base salary.
#           bonus (rate): the bonus rate. Default is .1.
#         Returns:
#           float: the total salary.
#
# DATA
#     skills = ['SQL', 'Python', 'Excel']
#
# FILE
#     /content/my_module.py

# %%
help(bonus_calculator)
# Out:
# Help on function bonus_calculator in module my_module:
#
# bonus_calculator(total, base)
#     calculate the bonus rate based on the total salary and the base salary.
#     Args:
#       total (float): the total salary.
#       base (float): the base salary.
#     Returns:
#       float: the bonus rate.

# %% [markdown]
# # Python Standard Library
# ## Statistics module

# %%
salary_list = [200000, 100000, 150000, 130000, 170000, 100000]

# %%
from statistics import mean, mode, median

# %%
mean(salary_list)
# Out:
# 150000

# %%
mode(salary_list)
# Out:
# 100000

# %%
median(salary_list)
# Out:
# 140000.0
