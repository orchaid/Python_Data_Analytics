# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python',' SQL,',' Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'PyTorch']", 'job_date': '2023-11-07'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'Excel', 'Tableau']", 'job_date': '2023-08-21'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'AWS']", 'job_date': '2023-02-15'},
    {'job_title': 'Business Intelligence Analyst', 'job_skills': "['SQL', 'Power BI', 'Data Visualization']", 'job_date': '2023-07-04'},
    {'job_title': 'AI Researcher', 'job_skills': "['Python', 'Deep Learning', 'NLP']", 'job_date': '2024-01-10'},
    {'job_title': 'Data Scientist', 'job_skills': "['R', 'SQL', 'Machine Learning']", 'job_date': '2023-12-20'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Java', 'TensorFlow', 'Kubernetes']", 'job_date': '2024-03-05'},
    {'job_title': 'Data Analyst', 'job_skills': "['Excel', 'VBA', 'Power BI']", 'job_date': '2023-09-18'}
]

# %% [markdown]
# # Using python built-in libraries
# - `datetime` -- Basic date and data type -> *important*
# - `ast` -- abstract syntax trees
#
# *U can find info about python libraries in*
# -  url: docs.python.org/3/library/datetime.html
# -  url: docs.python.org/3/library/ast.html

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 1, 25, 1, 55, 19, 977464)

# %%
print(datetime.now()) # in date and time YYYY-mm-dd hh-mm-ss

# %% [markdown]
# The problem with our data above is:
# - the date is in str data type -> solve using `datetime`
# - the list in job_skills column is str because of "[ ]" -> solve using `literal_eval`

# %%
data_science_jobs[0]['job_skills'] # to see the first(job_title) row in the second(job_skills) column
# I can use index because its a dict within list
# Out:
# "['Python',' SQL,',' Machine Learning']"

# %%
data_science_jobs[0]['job_date']
# Out:
# '2023-05-12'

# %%
type(data_science_jobs[0]['job_date']) #  it's a str
# Out:
# str

# %%
test_date = data_science_jobs[0]['job_date']
trial
# Out:
# '2023-05-12'

# %%
#to turn it into datetime at once, I used a classmethod called strptime
datetime.strptime(test_date,'%Y-%m-%d') # if i dont want the additional time import the method date and use it instead of datetime
# Out:
# datetime.datetime(2023, 5, 12, 0, 0)

# %%
for job in data_science_jobs: #job which is a dict now -> loop it change it's data type using strptime
  job['job_date'] = datetime.strptime(job['job_date'],'%Y-%m-%d') # assign the changed data type of job_date into a new one inside the original list

# %%
type (data_science_jobs[0]['job_date'])
# Out:
# datetime.datetime

# %%
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': "['Python',' SQL,',' Machine Learning']",
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': "['Python', 'TensorFlow', 'PyTorch']",
#   'job_date': datetime.datetime(2023, 11, 7, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': "['SQL', 'Excel', 'Tableau']",
#   'job_date': datetime.datetime(2023, 8, 21, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': "['Python', 'Spark', 'AWS']",
#   'job_date': datetime.datetime(2023, 2, 15, 0, 0)},
#  {'job_title': 'Business Intelligence Analyst',
#   'job_skills': "['SQL', 'Power BI', 'Data Visualization']",
#   'job_date': datetime.datetime(2023, 7, 4, 0, 0)},
#  {'job_title': 'AI Researcher',
#   'job_skills': "['Python', 'Deep Learning', 'NLP']",
#   'job_date': datetime.datetime(2024, 1, 10, 0, 0)},
#  {'job_title': 'Data Scientist',
#   'job_skills': "['R', 'SQL', 'Machine Learning']",
# ...

# %%
# literal_eval convert it into what it should be
import ast
for skill in data_science_jobs:
  skill['job_skills'] = ast.literal_eval(skill['job_skills'])

# %%
# # I could've done the previous two code in one if I wanted
# for job in data_science_jobs:
#   job['job_date'] = datetime.strptime(job['job_date'],'%Y-%m-%d')
#   job['job_skills'] = ast.literal_eval(job['job_skills'])

# %%
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', ' SQL,', ' Machine Learning'],
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'PyTorch'],
#   'job_date': datetime.datetime(2023, 11, 7, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': ['SQL', 'Excel', 'Tableau'],
#   'job_date': datetime.datetime(2023, 8, 21, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': ['Python', 'Spark', 'AWS'],
#   'job_date': datetime.datetime(2023, 2, 15, 0, 0)},
#  {'job_title': 'Business Intelligence Analyst',
#   'job_skills': ['SQL', 'Power BI', 'Data Visualization'],
#   'job_date': datetime.datetime(2023, 7, 4, 0, 0)},
#  {'job_title': 'AI Researcher',
#   'job_skills': ['Python', 'Deep Learning', 'NLP'],
#   'job_date': datetime.datetime(2024, 1, 10, 0, 0)},
#  {'job_title': 'Data Scientist',
#   'job_skills': ['R', 'SQL', 'Machine Learning'],
# ...
